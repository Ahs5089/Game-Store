# %% [markdown]
# # **Overview**.
#
# The gaming industry is certainly one of the thriving industries of the modern age and one of those that are most influenced by the advancement in technology. With the availability of technologies like AR/VR in consumer products like gaming consoles and even smartphones, the gaming sector shows great potential. In this hackathon, you as a data scientist must use your analytical skills to predict the sales of video games depending on given factors. Given are **8 distinguishing factors** that can influence the sales of a video game. Your objective as a data scientist is to build a machine learning model that can accurately predict the sales in millions of units for a given game.

# %% [markdown]
# Project dataset source link: [MachineHack Hackathon](https://machinehack.com/hackathon/video_game_sales_prediction_weekend_hackathon_10/data)

# %% [markdown]
# After registering for the hackathon we receive 3 files viz. Sample submission, Train and Test.csv.

# %% [markdown]
# **Data Description**:-
# The unzipped folder will have the following files.
#
# Train.csv –  3506 observations.
# Test.csv –  1503 observations.
# Sample Submission – Sample format for the submission.
# **Target Variable**: SalesInMillions

# %% [markdown]
# Once downloaded we can run below code cell to upload the files to this notebook. Run the below code cell, then click on `Choose Files` button to upload files to google colab.

# %%
# from Jupyter.notebook import files
# uploaded = files.upload()
# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))

# %% [markdown]
# # File Imports

# %%
#Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Read the csv files
input = pd.read_csv("Train.csv")

# %%
#print all columns to understand the dataset
input.head()
# Out:
#      ID CONSOLE  YEAR      CATEGORY                     PUBLISHER RATING  \
# 0  2860      ds  2008  role-playing                      Nintendo      E
# 1   731     wii  2012    simulation  Konami Digital Entertainment   E10+
# 2   495      pc  2019       shooter                    Activision      M
# 3  2641     ps2  2002        sports               Electronic Arts      E
# 4   811     ps3  2013        action                    Activision      M
#
#    CRITICS_POINTS  USER_POINTS  SalesInMillions
# 0        2.833333     0.303704         1.779257
# 1       13.200000     1.640000         0.215050
# 2        4.562500     0.006410         0.534402
# 3        4.181818     0.326923         1.383964
# 4        2.259259     0.032579         0.082671

# %% [markdown]
# # Data cleaning

# %%
input.isnull().sum()
# Out:
# ID                 0
# CONSOLE            0
# YEAR               0
# CATEGORY           0
# PUBLISHER          0
# RATING             0
# CRITICS_POINTS     0
# USER_POINTS        0
# SalesInMillions    0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset. So we can move to the next step of removing unnecessary columns.

# %% [markdown]
# From dataset, we can observe that except `id` column, all the other columns play a significant role in final sales of videogames. So it can be dropped.

# %%
input = input.drop(columns=['ID'])
train, test = train_test_split(input, test_size=0.2, random_state=42, shuffle=True)

# %% [markdown]
# # Descriptive Statistics

# %%
train.shape, test.shape
# Out:
# ((2804, 8), (702, 8))

# %%
train.nunique()
# Out:
# CONSOLE              17
# YEAR                 23
# CATEGORY             12
# PUBLISHER           184
# RATING                6
# CRITICS_POINTS     1499
# USER_POINTS        1875
# SalesInMillions    2804
# dtype: int64

# %%
#If you are seeing the output below for the first time visit this link
#to understand what the values in each of this rows(mean, std, min, max) actually
#are:- https://www.w3resource.com/pandas/dataframe/dataframe-describe.php
train.describe()
# Out:
#               YEAR  CRITICS_POINTS  USER_POINTS  SalesInMillions
# count  2804.000000     2804.000000  2804.000000      2804.000000
# mean   2008.982168        3.748742     0.403144         2.184942
# std       4.286690        3.101958     0.455677         2.578479
# min    1997.000000        0.568966     0.000341         0.001524
# 25%    2006.000000        1.735220     0.063171         0.952236
# 50%    2009.000000        2.745968     0.229331         1.863315
# 75%    2012.000000        4.555556     0.600000         2.807032
# max    2019.000000       23.250000     2.325000        84.226041

# %% [markdown]
# From above table, my first insight is I can create bar charts of **console, year**, **category** and **ratings** columns easily. For other columns I might have to go for some other visual representation since the the number of unique values is high.

# %% [markdown]
# *   From **SalesInMillions** column we can see that average
# sales have been around 2 million and max sales have reached a mark of about 84 million🤩 and min sales were around just 1500😔.
# *   From **year** column we can see that data covers sales from the year 1997 to 2019
# *   **Critic Points** range from 0.5 to 23.25 while **user points** range from 0.0003 to 2.32. We might need to noramlise this values on same scale else critic points will have higher impact than user points on final prediction although in reality both of them should have equal importance.

# %% [markdown]
# # EDA

# %% [markdown]
# I am first opting for auto EDA packages like pandas-profiling for generating visualisations and there corresponding reports.

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# Collecting https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Using cached https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: scipy<1.12,>=1.4.1 in d:\visual\visualvenv\lib\site-packages (from ydata-profiling==0.0.dev0) (1.11.2)
# Collecting pandas!=1.4.0,<2.1,>1.1 (from ydata-profiling==0.0.dev0)
#   Obtaining dependency information for pandas!=1.4.0,<2.1,>1.1 from https://files.pythonhosted.org/packages/9e/71/756a1be6bee0209d8c0d8c5e3b9fc72c00373f384a4017095ec404aec3ad/pandas-2.0.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached pandas-2.0.3-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: matplotlib<4,>=3.2 in d:\visual\visualvenv\lib\site-packages (from ydata-profiling==0.0.dev0) (3.7.3)
# Collecting pydantic<2,>=1.8.1 (from ydata-profiling==0.0.dev0)
#   Obtaining dependency information for pydantic<2,>=1.8.1 from https://files.pythonhosted.org/packages/e1/6b/6a68bd4f0837accdb78cf07e8590f2c9f00334003681b94d4957424248f2/pydantic-1.10.12-cp311-cp311-win_amd64.whl.metadata
#   Using cached pydantic-1.10.12-cp311-cp311-win_amd64.whl.metadata (150 kB)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in d:\visual\visualvenv\lib\site-packages (from ydata-profiling==0.0.dev0) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in d:\visual\visualvenv\lib\site-packages (from ydata-profiling==0.0.dev0) (3.1.2)
# Collecting visions[type_image_path]==0.7.5 (from ydata-profiling==0.0.dev0)
#   Using cached visions-0.7.5-py3-none-any.whl (102 kB)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in d:\visual\visualvenv\lib\site-packages (from ydata-profiling==0.0.dev0) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in d:\visual\visualvenv\lib\site-packages (from ydata-profiling==0.0.dev0) (0.1.12)
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling==0.0.dev0)
#   Using cached phik-0.12.3-cp311-cp311-win_amd64.whl (663 kB)
# Collecting requests<3,>=2.24.0 (from ydata-profiling==0.0.dev0)
#   Obtaining dependency information for requests<3,>=2.24.0 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm<5,>=4.48.2 in d:\visual\visualvenv\lib\site-packages (from ydata-profiling==0.0.dev0) (4.66.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in d:\visual\visualvenv\lib\site-packages (from ydata-profiling==0.0.dev0) (0.12.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling==0.0.dev0)
#   Using cached multimethod-1.9.1-py3-none-any.whl (10 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling==0.0.dev0)
#   Using cached statsmodels-0.14.0-cp311-cp311-win_amd64.whl (9.2 MB)
# Requirement already satisfied: typeguard<3,>=2.13.2 in d:\visual\visualvenv\lib\site-packages (from ydata-profiling==0.0.dev0) (2.13.3)
# Collecting imagehash==4.3.1 (from ydata-profiling==0.0.dev0)
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Collecting wordcloud>=1.9.1 (from ydata-profiling==0.0.dev0)
#   Obtaining dependency information for wordcloud>=1.9.1 from https://files.pythonhosted.org/packages/34/ac/72a4e42e76bf549dfd91791a6b10a9832f046c1d48b5e778be9ec012aa47/wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling==0.0.dev0)
#   Obtaining dependency information for dacite>=1.8 from https://files.pythonhosted.org/packages/21/0f/cf0943f4f55f0fbc7c6bd60caf1343061dff818b02af5a0d444e473bb78d/dacite-1.8.1-py3-none-any.whl.metadata
#   Using cached dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling==0.0.dev0)
#   Using cached PyWavelets-1.4.1-cp311-cp311-win_amd64.whl (4.2 MB)
# Requirement already satisfied: pillow in d:\visual\visualvenv\lib\site-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (10.0.0)
# Collecting attrs>=19.3.0 (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Requirement already satisfied: networkx>=2.4 in d:\visual\visualvenv\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in d:\visual\visualvenv\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\visual\visualvenv\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==0.0.dev0) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\visual\visualvenv\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in d:\visual\visualvenv\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\visual\visualvenv\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\visual\visualvenv\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\visual\visualvenv\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\visual\visualvenv\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\visual\visualvenv\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\visual\visualvenv\lib\site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling==0.0.dev0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\visual\visualvenv\lib\site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling==0.0.dev0) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in d:\visual\visualvenv\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling==0.0.dev0) (1.3.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\visual\visualvenv\lib\site-packages (from pydantic<2,>=1.8.1->ydata-profiling==0.0.dev0) (4.7.1)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/91/6e/db0e545302bf93b6dbbdc496dd192c7f8e8c3bb1584acba069256d8b51d4/charset_normalizer-3.2.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached charset_normalizer-3.2.0-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\visual\visualvenv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (2.0.4)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting patsy>=0.5.2 (from statsmodels<1,>=0.13.2->ydata-profiling==0.0.dev0)
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: colorama in d:\visual\visualvenv\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling==0.0.dev0) (0.4.6)
# Requirement already satisfied: six in d:\visual\visualvenv\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling==0.0.dev0) (1.16.0)
# Using cached dacite-1.8.1-py3-none-any.whl (14 kB)
# Using cached pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
# Using cached pydantic-1.10.12-cp311-cp311-win_amd64.whl (2.1 MB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached wordcloud-1.9.2-cp311-cp311-win_amd64.whl (151 kB)
# Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Using cached charset_normalizer-3.2.0-cp311-cp311-win_amd64.whl (96 kB)
# Building wheels for collected packages: ydata-profiling
#   Building wheel for ydata-profiling (pyproject.toml): started
#   Building wheel for ydata-profiling (pyproject.toml): finished with status 'done'
#   Created wheel for ydata-profiling: filename=ydata_profiling-0.0.dev0-py2.py3-none-any.whl size=357400 sha256=cf4f0ed718d0330275fdf6d5e5246f251004e421411094921b02e8d6fbd6629f
#   Stored in directory: C:\Users\shaik\AppData\Local\Temp\pip-ephem-wheel-cache-mo9tkspq\wheels\85\5d\45\8a23c7b77d2023fbc37490b8902f7fdeff5614f65d6e08b6c4
# Successfully built ydata-profiling
# Installing collected packages: PyWavelets, pydantic, patsy, multimethod, idna, dacite, charset-normalizer, certifi, attrs, requests, pandas, imagehash, wordcloud, visions, statsmodels, phik, ydata-profiling
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.0
#     Uninstalling pandas-2.1.0:
#       Successfully uninstalled pandas-2.1.0
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'D:\\visual\\visualvenv\\Lib\\site-packages\\~andas.libs\\msvcp140-59fdf63e48138046aebeb6ddb5b4e960.dll'
# Check the permissions.

# %%
from pandas_profiling import ProfileReport
report = ProfileReport(train, title="Report", html={'style': {'full_width':True}}, explorative=True, missing_diagrams={'bar': True})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\visual\Game store\Copy of Video_Game_Sales_prediction.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/visual/Game%20store/Copy%20of%20Video_Game_Sales_prediction.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> from pandas_profiling import ProfileReport
#       <a href='vscode-notebook-cell:/d%3A/visual/Game%20store/Copy%20of%20Video_Game_Sales_prediction.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> report = ProfileReport(train, title="Report", html={'style': {'full_width':True}}, explorative=True, missing_diagrams={'bar': True})
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
report.to_notebook_iframe()

# %%
#Save the report in file
report.to_file("pandas_profiling_report.html")

# %% [markdown]
# From the above reports we can gain following insights:-
# *   Console column graph:
# <img src="https://res.cloudinary.com/dk22rcdch/image/upload/v1595439244/VideoGameDatasetAnalysisImages/Screenshot_2020-07-22_at_11.02.44_PM_nxz5cm.png" width=400>
# The sales of **PS2** were the highest in the data set
#
# *   Years Column graph:
# <img src="https://res.cloudinary.com/dk22rcdch/image/upload/v1595439371/VideoGameDatasetAnalysisImages/Screenshot_2020-07-22_at_11.05.51_PM_ycn3nl.png" width=400>
# The sales were highest between the period **2005-2010**.
#
# *   Game category column graph:
# <img src="https://res.cloudinary.com/dk22rcdch/image/upload/v1595439531/VideoGameDatasetAnalysisImages/Screenshot_2020-07-22_at_11.08.40_PM_ugwpdi.png" width=400>
#   **Action** category games are most popular

# %% [markdown]
# Now let's compare individual columns with target(SalesInMillions) column to gain a few more insights into the data.

# %%
#Sales of games that happened corresponding to each console.
df = pd.DataFrame(train.groupby(['CONSOLE']).agg({'SalesInMillions': 'sum'}))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\visual\Game store\Copy of Video_Game_Sales_prediction.ipynb Cell 33 line 2
#       <a href='vscode-notebook-cell:/d%3A/visual/Game%20store/Copy%20of%20Video_Game_Sales_prediction.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> #Sales of games that happened corresponding to each console.
# ----> <a href='vscode-notebook-cell:/d%3A/visual/Game%20store/Copy%20of%20Video_Game_Sales_prediction.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> df = pd.DataFrame(train.groupby(['CONSOLE']).agg({'SalesInMillions': 'sum'}))
#
# NameError: name 'pd' is not defined

# %%
df.plot.bar(figsize=(12, 6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\visual\Game store\Copy of Video_Game_Sales_prediction.ipynb Cell 34 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/visual/Game%20store/Copy%20of%20Video_Game_Sales_prediction.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> df.plot.bar(figsize=(12, 6))
#
# NameError: name 'df' is not defined

# %% [markdown]
# **💡Insight**:  From the above graph we can see that sales were highest for PS3 platform followed by Xbox360

# %%
df = pd.DataFrame(train.groupby(['YEAR']).agg({'SalesInMillions': 'sum'}))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\visual\Game store\Copy of Video_Game_Sales_prediction.ipynb Cell 36 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/visual/Game%20store/Copy%20of%20Video_Game_Sales_prediction.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> df = pd.DataFrame(train.groupby(['YEAR']).agg({'SalesInMillions': 'sum'}))
#
# NameError: name 'pd' is not defined

# %%
df.plot.bar(figsize=(12, 6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\visual\Game store\Copy of Video_Game_Sales_prediction.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/visual/Game%20store/Copy%20of%20Video_Game_Sales_prediction.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> df.plot.bar(figsize=(12, 6))
#
# NameError: name 'df' is not defined

# %% [markdown]
# **💡Insight**:  From the above graph we can see that sales were highest in the year 2010

# %%
df = pd.DataFrame(train.groupby(['CATEGORY']).agg({'SalesInMillions': 'sum'}))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\visual\Game store\Copy of Video_Game_Sales_prediction.ipynb Cell 39 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/visual/Game%20store/Copy%20of%20Video_Game_Sales_prediction.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> df = pd.DataFrame(train.groupby(['CATEGORY']).agg({'SalesInMillions': 'sum'}))
#
# NameError: name 'pd' is not defined

# %%
df.plot.bar(figsize=(12, 6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\visual\Game store\Copy of Video_Game_Sales_prediction.ipynb Cell 40 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/visual/Game%20store/Copy%20of%20Video_Game_Sales_prediction.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> df.plot.bar(figsize=(12, 6))
#
# NameError: name 'df' is not defined

# %% [markdown]
# **💡Insight**:  From the above graph we can see that sales were highest for action genre

# %% [markdown]
# # Model training

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Obtaining dependency information for catboost from https://files.pythonhosted.org/packages/bc/a6/5abbac311fbcaeee79e13c468cd9535f02296ca1a7b0e44d6f468fa83434/catboost-1.2.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached catboost-1.2.1-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in d:\visual\visualvenv\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in d:\visual\visualvenv\lib\site-packages (from catboost) (3.7.3)
# Requirement already satisfied: numpy>=1.16.0 in d:\visual\visualvenv\lib\site-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in d:\visual\visualvenv\lib\site-packages (from catboost) (2.1.0)
# Requirement already satisfied: scipy in d:\visual\visualvenv\lib\site-packages (from catboost) (1.11.2)
# Requirement already satisfied: plotly in d:\visual\visualvenv\lib\site-packages (from catboost) (5.16.1)
# Requirement already satisfied: six in d:\visual\visualvenv\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\visual\visualvenv\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\visual\visualvenv\lib\site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\visual\visualvenv\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\visual\visualvenv\lib\site-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in d:\visual\visualvenv\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\visual\visualvenv\lib\site-packages (from matplotlib->catboost) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\visual\visualvenv\lib\site-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\visual\visualvenv\lib\site-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\visual\visualvenv\lib\site-packages (from matplotlib->catboost) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\visual\visualvenv\lib\site-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in d:\visual\visualvenv\lib\site-packages (from plotly->catboost) (8.2.3)
# Using cached catboost-1.2.1-cp311-cp311-win_amd64.whl (101.0 MB)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.1

# %%
import catboost as cat
cat_feat = ['CONSOLE','CATEGORY', 'PUBLISHER', 'RATING']
features = list(set(train.columns)-set(['SalesInMillions']))
target = 'SalesInMillions'
model = cat.CatBoostRegressor(random_state=100,cat_features=cat_feat,verbose=0)
model.fit(train[features],train[target])

# %% [markdown]
# # Model Accuracy

# %%
y_true= pd.DataFrame(data=test[target], columns=['SalesInMillions'])
test_temp = test.drop(columns=[target])

# %%
y_pred = model.predict(test_temp[features])

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(y_true, y_pred))
print(rmse)

# %%
import pickle
filename = 'finalized_model.sav'

# %%
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
test_temp[features].head(1)

# %%
loaded_model.predict(test_temp[features].head(1))

# %%
from google.colab import drive
drive.mount('/content/drive')
